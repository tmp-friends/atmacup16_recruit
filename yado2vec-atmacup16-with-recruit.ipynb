# %% [markdown]
# # yado2vec - atmaCup16 with RECRUIT
#
# - gensimでitem2vec
# - 各itemに対し類似度が上位のアイテムK件と、すべてのベクトルデータを保存

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.3.0)

# %%
import pandas as pd
import numpy as np

# %%
class CFG:
    seed = 127
    top_n = 50
    
    # model
    vector_size = 64
    epochs = 50
    min_count = 1
    workers =4

# %% [markdown]
# ## Load data

# %%
train_logs_df = pd.read_csv("/kaggle/input/atmacup16-recruit/train_log.csv")
test_logs_df = pd.read_csv("/kaggle/input/atmacup16-recruit/test_log.csv")

# %% [markdown]
# ## Preprocess

# %%
# train, testのログデータをconcat
logs_df = pd.concat([train_logs_df, test_logs_df], axis=0)
logs_df = logs_df.drop(columns=["seq_no"])

# session_idごとにyad_noをリストにまとめる
sentences = logs_df.groupby("session_id")["yad_no"].apply(list).tolist()

# %%
sentences[:10]
# Out:
# [[2395],
#  [3560, 1959],
#  [13535],
#  [123],
#  [11984],
#  [757, 8922],
#  [8475],
#  [96, 898],
#  [6868],
#  [8602]]

# %% [markdown]
# ## Fit

# %%
from gensim.models.word2vec import Word2Vec

w2v_params = {
    "vector_size": CFG.vector_size,
    "epochs": CFG.epochs,
    "seed": CFG.seed,
    "min_count": CFG.min_count,
    "workers": CFG.workers,
}

model = Word2Vec(sentences, **w2v_params)

# %% [markdown]
# ## 定性評価

# %%
yados_df = pd.read_csv("/kaggle/input/atmacup16-recruit/yado.csv")

# %%
target_yad_no = 11089
res = model.wv.most_similar(target_yad_no, topn=10)

res
# Out:
# [(6800, 0.9979557394981384),
#  (3432, 0.9975354075431824),
#  (3782, 0.9974309802055359),
#  (6799, 0.9973302483558655),
#  (9609, 0.9969385266304016),
#  (7211, 0.9969350099563599),
#  (4771, 0.9966328740119934),
#  (5671, 0.9960944652557373),
#  (4516, 0.9958534240722656),
#  (11690, 0.9940141439437866)]

# %%
similar_items = [v for v, _ in res]
similar_items.insert(0, target_yad_no)

similar_items
# Out:
# [11089, 6800, 3432, 3782, 6799, 9609, 7211, 4771, 5671, 4516, 11690]

# %%
yados_df[yados_df["yad_no"].isin(similar_items)]
# Out:
#        yad_no  yad_type  total_room_cnt  wireless_lan_flg  onsen_flg  \
# 3431     3432         0            38.0               1.0          0
# 3781     3782         0           161.0               1.0          0
# 4515     4516         0            35.0               1.0          0
# 4770     4771         0           110.0               1.0          0
# 5670     5671         0            84.0               1.0          0
# 6798     6799         0           190.0               1.0          0
# 6799     6800         0            62.0               1.0          0
# 7210     7211         0           245.0               1.0          0
# 9608     9609         0            29.0               1.0          0
# 11088   11089         0             NaN               1.0          0
# 11689   11690         0            45.0               1.0          0
#
#        kd_stn_5min  kd_bch_5min  kd_slp_5min  kd_conv_walk_5min  \
# 3431           1.0          NaN          NaN                1.0
# 3781           NaN          NaN          NaN                NaN
# 4515           NaN          NaN          NaN                NaN
# 4770           1.0          NaN          NaN                1.0
# 5670           1.0          NaN          NaN                1.0
# 6798           1.0          NaN          NaN                1.0
# 6799           1.0          NaN          NaN                1.0
# 7210           1.0          NaN          NaN                1.0
# 9608           1.0          NaN          NaN                1.0
# 11088          1.0          NaN          NaN                1.0
# 11689          NaN          NaN          NaN                NaN
#
#                                  wid_cd                            ken_cd  \
# 3431   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 3781   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 4515   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 4770   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 5670   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 6798   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 6799   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 7210   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 9608   46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 11088  46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
# 11689  46e33861f921c3e38b81998fbf283f01  83522288daa2f3a0010f79df27c38ea5
#
#                                  lrg_cd                            sml_cd
# 3431   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 3781   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 4515   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 4770   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 5670   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 6798   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 6799   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 7210   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 9608   848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 11088  848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706
# 11689  848dd393c353d8d0e63080af42d99e49  95eac355ee029b439925bf7098836706

# %% [markdown]
# ## Infer

# %%
# 近いアイテム
similar_items = {}
vecs = {}
for yad_no in yados_df["yad_no"].values:
    if yad_no not in model.wv.key_to_index:
        continue
        
    res = model.wv.most_similar(yad_no, topn=CFG.top_n)
    
    # 類似アイテム
    similar_items[yad_no] = [v for v, _ in res]
    
    # ベクトルデータ
    vecs[yad_no] = model.wv[yad_no]

# %%
print(f"yad.csvに含まれるアイテム数: {yados_df['yad_no'].nunique()}")
print(f"yad2vecに含まれるアイテム数: {len(similar_items)}")
# Out:
# yad.csvに含まれるアイテム数: 13806
# yad2vecに含まれるアイテム数: 13562

# %%
similar_items_df = pd.DataFrame.from_dict(similar_items, orient="index")
similar_items_df.columns = [f"item{v}" for v in range(CFG.top_n)]

# 保存
similar_items_df.to_csv("y2v_items.csv", index_label="Key")

# %%
similar_items_df
# Out:
#        item0  item1  item2  item3  item4  item5  item6  item7  item8  item9  \
# 1      10870   5198   1254   1503   6192   3796  10950   1474   9789  10248
# 2      13783   3860  12162   3847    299   7597  12232     36   7765  13333
# 3       6579   9624    846  10439  11295  12154  10415    420   5294   6247
# 4        430   3054  11408  10599   8899   9041  10186   9631   1896   8617
# 5      12782   1901    117   9493   5606  13654  10549   7277   6241   3928
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 13801  12634    205  10601   2747    627   5909   4674   9310   9448   9198
# 13803  12752   1362   6883  12558  12775   7251   9470   3512   8724   7558
# 13804  12835   8908  11633   1174  10809    518    376  13382   3389   4416
# 13805  12692   2917   5068  10359   4635   6615   3413   2906  11610     61
# 13806   3628   6141   5265   3798   4367    211   4875  10208  11113    334
#
#        ...  item40  item41  item42  item43  item44  item45  item46  item47  \
# 1      ...    2245    3595    1400    2988    4221    8787   13647    8207
# 2      ...    5478   13174     440   10590   11080     446    6509   11459
# 3      ...   12178    5941    2974    4825    3931    2284   12646    9545
# 4      ...    9545    2018    1779    4879   11445    8609    7093    2574
# 5      ...    3030   11067    5655    7602    4324    3137   12684    8919
# ...    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 13801  ...    3401   10767     119    7891   10150     496    3579    7182
# 13803  ...    9161    5241    9240    1408    1052    3879     253   13092
# 13804  ...    8848    7903    9244    2983    9584   10137   11383    1450
# 13805  ...   11053   11582    5257     433    6919    5637    3788    8195
# 13806  ...    4224    4221    5206    7652    6747    3595    3840    6574
#
#        item48  item49
# 1        4224    3350
# 2        7177    8375
# 3        7561    1229
# 4        3137    4829
# 5       11445    1983
# ...       ...     ...
# 13801    1841   12672
# 13803    6074   11330
# 13804   12289    8582
# 13805   11020   11325
# 13806    2245    9809
#
# [13562 rows x 50 columns]

# %%
vecs_df = pd.DataFrame.from_dict(vecs, orient="index")
vecs_df.columns = [f"vec{v}" for v in range(CFG.vector_size)]

# 保存
vecs_df.to_csv("y2v_vecs.csv", index_label="Key")

# %%
vecs_df
# Out:
#            vec0      vec1      vec2      vec3      vec4      vec5      vec6  \
# 1     -0.056160  0.461323 -0.246454 -0.097147 -0.747485  0.106123 -0.327350
# 2     -0.380085  0.017703 -0.180225 -0.431436 -0.240020  0.061820  0.259663
# 3      0.159336 -0.469314  0.011676 -1.861795 -0.705575  0.016262  0.661346
# 4     -0.304735 -0.183908 -0.284408 -1.307295 -0.493841 -0.378975  0.623894
# 5     -0.037937  0.050301 -0.093290 -0.216820 -0.272093 -0.036300  0.226241
# ...         ...       ...       ...       ...       ...       ...       ...
# 13801 -0.408353  0.464413  0.379729 -0.791758 -0.762315 -0.129494  0.942803
# 13803 -0.231795  0.198019  0.330224 -0.366481 -0.144736  0.045544 -0.263635
# 13804  0.076345  0.452165  0.019554 -0.028466  0.079052  0.281892  0.566528
# 13805 -0.059402  0.010639 -0.064069 -0.123300 -0.155746  0.096167  0.010204
# 13806  0.064450  0.418131 -0.395033  0.062916 -1.143383 -0.135601 -0.068626
#
#            vec7      vec8      vec9  ...     vec54     vec55     vec56  \
# 1     -0.604765 -0.297258  0.207103  ... -0.157627  0.238811 -0.049458
# 2     -0.285451  0.108400  0.000869  ... -0.297499  0.388696  0.510876
# 3     -0.469468  0.279515 -0.695082  ...  0.283484 -0.366958  1.687001
# 4     -0.324846  0.180742 -0.619462  ... -0.279539  0.340182  1.288328
# 5     -0.000820  0.580219 -0.732586  ...  0.127412  0.818064  0.852673
# ...         ...       ...       ...  ...       ...       ...       ...
# 13801 -0.683183 -0.297677  0.141463  ... -0.167150  0.682974  0.646733
# 13803 -0.306815  0.101774  0.238183  ... -0.884420  0.493421  0.477872
# 13804 -0.403330  0.042952 -0.933820  ... -0.231951  0.103499  1.004862
# 13805 -0.181731 -0.033994 -0.062645  ...  0.001008  0.111483  0.241450
# 13806 -0.596373  0.186060 -0.643210  ...  0.251554  0.441604  0.565171
#
#           vec57     vec58     vec59     vec60     vec61     vec62     vec63
# 1      0.214988  0.130053  0.306387 -0.045955  0.308469 -0.010767  0.501859
# 2      0.191163 -0.259338  0.047039 -0.535272  0.248897 -0.288526 -0.151147
# 3      0.727565  0.043843  0.316751 -0.492664 -0.411019 -0.298784 -0.889309
# 4      0.591720 -0.228116 -0.138246 -0.428144 -0.731898 -0.320868 -0.465543
# 5      0.914156 -0.192551  0.087662 -0.227779 -0.336038  0.195412 -0.117620
# ...         ...       ...       ...       ...       ...       ...       ...
# 13801 -0.749047 -0.358897 -0.264624 -0.363424  0.111278  0.726910 -0.574798
# 13803  0.596923  0.124741 -0.118186 -0.222710 -0.187648  0.094433  0.400136
# 13804  0.509584 -0.047070  0.019413 -0.444506  0.065724 -0.498774 -0.253588
# 13805  0.114779  0.037387  0.088836 -0.048148 -0.055917  0.095358 -0.075880
# 13806  0.801662  0.499459 -0.275639 -0.486460  0.398141  0.041349  0.548292
#
# [13562 rows x 64 columns]
